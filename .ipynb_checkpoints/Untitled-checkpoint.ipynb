# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import Ridge
from mlxtend.feature_selection import SequentialFeatureSelector
from mlxtend.feature_selection import ExhaustiveFeatureSelector
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from tqdm import tqdm
from itertools import product
from scipy.optimize import minimize
from sklearn.feature_selection import SelectFromModel
import warnings
warnings.filterwarnings('ignore')
sns.set(style='whitegrid')

# %% [markdown]
# ### Исходный датасет

# %%
data = pd.read_excel('vr_rd.xlsx')

# %%
data.head()
# Out:
#                       Date    Income   Outcome   Balance
# 0  2017-01-09 00:00:00.000  1.343028  1.487865 -0.155904
# 1  2017-01-10 00:00:00.000  1.068610  1.194182 -0.125572
# 2  2017-01-11 00:00:00.000  0.944429  0.936663  0.007767
# 3  2017-01-12 00:00:00.000  1.672202  0.875379  0.800391
# 4  2017-01-13 00:00:00.000  0.955924  0.975645 -0.019721

# %%
data.isna().sum()
# Out:
# Date       0
# Income     0
# Outcome    0
# Balance    0
# dtype: int64

# %% [markdown]
# ### Датасет с доп.признаками

# %% [markdown]
# ### m0	- Денежный агрегат М0
# ### m1	- Денежный агрегат М1
# ### m2	- Денежный агрегат М2
# ### wide_money_supply - Широкая денежная масса
# ### domestic_deposit - Остальные депозиты в рублях
# ### domestic_deposit_transfer - Переводные депозиты в рублях
# ### domestic_deposit_transfer_fin - Переводные депозиты в рублях финансовых организаций
# ### domestic_deposit_transfer_nonfin - Переводные депозиты в рублях нефинансовых организаций
# ### domestic_deposit_fin - Остальные депозиты в рублях финансовых организаций
# ### domestic_deposit_nonfin	- Остальные депозиты в рублях нефинансовых организаций
# ### foreign_deposit	- Депозиты в иностранной валюте
# ### foreign_deposit_fin - Депозиты в иностранной валюте финансовых организаций
# ### foreign_deposit_nonfin - Депозиты в иностранной валюте нефинансовых организаций

# %%
data_mdf = pd.read_excel('vr_rd_fin.xlsx')

# %%
data_mdf.head()
# Out:
#          Date    income   outcome   balance   bid  bid_days_change  day_week  \
# 0  2017-01-09  1.343028  1.487865 -0.155904  10.0                1         0
# 1  2017-01-10  1.068610  1.194182 -0.125572  10.0                0         1
# 2  2017-01-11  0.944429  0.936663  0.007767  10.0                0         2
# 3  2017-01-12  1.672202  0.875379  0.800391  10.0                0         3
# 4  2017-01-13  0.955924  0.975645 -0.019721  10.0                0         4
#
#    day_month  month  year  ...  wide_money_supply  domestic_deposit  \
# 0          9      1  2017  ...            50895.2           20775.6
# 1         10      1  2017  ...            50895.2           20775.6
# 2         11      1  2017  ...            50895.2           20775.6
# 3         12      1  2017  ...            50895.2           20775.6
# 4         13      1  2017  ...            50895.2           20775.6
#
#    domestic_deposit_transfer  domestic_deposit_transfer_fin  \
# ...

# %%
data_mdf.dtypes
# Out:
# Date                                 object
# income                              float64
# outcome                             float64
# balance                             float64
# bid                                 float64
# bid_days_change                       int64
# day_week                              int64
# day_month                             int64
# month                                 int64
# year                                  int64
# m0                                  float64
# m1                                  float64
# m2                                  float64
# wide_money_supply                   float64
# domestic_deposit                    float64
# domestic_deposit_transfer           float64
# domestic_deposit_transfer_fin       float64
# domestic_deposit_transfer_nonfin    float64
# domestic_deposit_fin                float64
# domestic_deposit_nonfin             float64
# foreign_deposit                     float64
# ...

# %%
data_mdf['Date'] = pd.to_datetime(data_mdf['Date'])

# %%
data_mdf.isna().sum()
# Out:
# Date                                  0
# income                                0
# outcome                               0
# balance                               0
# bid                                 490
# bid_days_change                       0
# day_week                              0
# day_month                             0
# month                                 0
# year                                  0
# m0                                    0
# m1                                    0
# m2                                    0
# wide_money_supply                     0
# domestic_deposit                      0
# domestic_deposit_transfer             0
# domestic_deposit_transfer_fin         0
# domestic_deposit_transfer_nonfin      0
# domestic_deposit_fin                  0
# domestic_deposit_nonfin               0
# foreign_deposit                       0
# foreign_deposit_fin                   0
# foreign_deposit_nonfin                0
# dtype: int64

# %%
data_mdf['bid'] = data_mdf['bid'].fillna(0)

# %%
def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))

        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5)

        print("Критерий Дики-Фуллера: p=%f" % sm.tsa.stattools.adfuller(y)[1])

        plt.tight_layout()
    return

# %%
tsplot(data_mdf['balance'], lags=30)
# Out:
# Критерий Дики-Фуллера: p=0.000918

# %%
ps = range(0, 5)
d=1
qs = range(0, 4)
Ps = range(0, 5)
D=1
Qs = range(0, 1)

parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)
# Out:
# 100

# %%
# %%time
results = []
best_aic = float("inf")

for param in tqdm(parameters_list):
    #try except нужен, потому что на некоторых наборах параметров модель не обучается
    try:
        model=sm.tsa.statespace.SARIMAX(data_mdf['balance'], order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 24*7)).fit(disp=-1)
    #выводим параметры, на которых модель не обучается и переходим к следующему набору
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    #сохраняем лучшую модель, aic, параметры
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])
    
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
# Out:
#   1%|          | 1/100 [00:30<50:07, 30.38s/it]

# %%
X = data_mdf.copy()
X.drop(columns=['balance', 'Date'], inplace = True)
y = data_mdf['balance']

# %%
X.isna().sum()
# Out:
# income                              0
# outcome                             0
# bid                                 0
# bid_days_change                     0
# day_week                            0
# day_month                           0
# month                               0
# year                                0
# m0                                  0
# m1                                  0
# m2                                  0
# wide_money_supply                   0
# domestic_deposit                    0
# domestic_deposit_transfer           0
# domestic_deposit_transfer_fin       0
# domestic_deposit_transfer_nonfin    0
# domestic_deposit_fin                0
# domestic_deposit_nonfin             0
# foreign_deposit                     0
# foreign_deposit_fin                 0
# foreign_deposit_nonfin              0
# dtype: int64

# %%
importances = mutual_info_regression(X, y)
feature_importances = pd.Series(importances, X.columns[0:len(data_mdf.columns)-1])
feature_importances.plot(kind='barh', color='teal')
plt.show()

# %%
efs = ExhaustiveFeatureSelector(LinearRegression(),
                                min_features=10,
          max_features=12,
          scoring='neg_mean_squared_error',
          cv=10)

efs = efs.fit(X, y)


selected_features = X_train.columns[list(efs.best_idx_)]
print(selected_features)

print(efs.best_score_)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2556\190274914.py in <module>
#       5           cv=10)
#       6
# ----> 7 efs = efs.fit(X, y)
#       8
#       9
#
# ~\anaconda3\lib\site-packages\mlxtend\feature_selection\exhaustive_feature_selector.py in fit(self, X, y, groups, **fit_params)
#     442         parallel = Parallel(n_jobs=n_jobs, pre_dispatch=self.pre_dispatch)
#     443         work = enumerate(
# --> 444             parallel(
#     445                 delayed(_calc_score)(
#     446                     self,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ...

# %%
linear = LinearRegression().fit(X, y)
model = SelectFromModel(linear, prefit=True)
X_new = model.transform(X)
selected_features = X.columns[list(X_new.best_idx_)]
print(selected_features)
selected_columns = selected_features.columns[selected_features.var() != 0]
print(selected_columns)

# %%
class Stat(object):
    def __init__(self, threshold, direction="unknown", init_stat=0.0):
        self._direction = str(direction)
        self._threshold = float(threshold)
        self._stat = float(init_stat)
        self._alarm = self._stat / self._threshold
    
    @classmethod
    def from_config(cls, config):
        check_empty_config(config)
        return cls(threshold=1.0)
    
    @property
    def direction(self):
        return self._direction

    @property
    def stat(self):
        return self._stat
        
    @property
    def alarm(self):
        return self._alarm
        
    @property
    def threshold(self):
        return self._threshold
    
    @property
    def debug_output(self):
        return {self.__class__.__name__: self.alarm}
        
    def update(self, **kwargs):
        # Statistics may use any of the following kwargs:
        #   ts - timestamp for the value
        #   value - original value
        #   mean - current estimated mean
        #   std - current estimated std
        #   adjusted_value - usually (value - mean) / std
        # Statistics call this after updating '_stat'
        self._alarm = self._stat / self._threshold
